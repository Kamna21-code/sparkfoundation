# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.cluster import KMeans

# %% [markdown]
# # Importing Dataset

# %%
df = pd.read_csv("iris.csv")
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %% [markdown]
# # Data Exploration

# %%
df.shape
# Out:
# (150, 6)

# %%
df.isnull().any()
# Out:
# Id               False
# SepalLengthCm    False
# SepalWidthCm     False
# PetalLengthCm    False
# PetalWidthCm     False
# Species          False
# dtype: bool

# %%
df.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
# Id               150 non-null int64
# SepalLengthCm    150 non-null float64
# SepalWidthCm     150 non-null float64
# PetalLengthCm    150 non-null float64
# PetalWidthCm     150 non-null float64
# Species          150 non-null object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
df['Species'].value_counts()
# Out:
# Iris-virginica     50
# Iris-setosa        50
# Iris-versicolor    50
# Name: Species, dtype: int64

# %% [markdown]
# # Data Visualization

# %%
sns.pairplot(df.drop('Id',axis = 1),hue = "Species",height = 3)
plt.show()

# %%
KS = {'color': ['blue', 'red', 'yellow']}
sns.FacetGrid(df, hue_kws=KS, hue="Species", height=5) \
   .map(plt.scatter, "SepalLengthCm", "SepalWidthCm") \
   .add_legend()
plt.show()

# %%
KS = {'color': ['blue', 'red', 'yellow']}
sns.FacetGrid(df, hue_kws=KS, hue="Species", height=5) \
   .map(plt.scatter, "PetalLengthCm", "PetalWidthCm") \
   .add_legend()
plt.show()

# %%
ax= sns.boxplot(x="Species", y="PetalLengthCm", data=df)
ax= sns.stripplot(x="Species", y="PetalLengthCm", data=df, jitter=True, edgecolor="gray")
plt.show()

# %%
ax= sns.boxplot(x="Species", y="SepalLengthCm", data=df)
ax= sns.stripplot(x="Species", y="SepalLengthCm", data=df, jitter=True, edgecolor="gray")
plt.show()

# %%
ax= sns.boxplot(x="Species", y="PetalWidthCm", data=df)
ax= sns.stripplot(x="Species", y="PetalWidthCm", data=df, jitter=True, edgecolor="gray")
plt.show()

# %%
ax= sns.boxplot(x="Species", y="SepalWidthCm", data=df)
ax= sns.stripplot(x="Species", y="SepalWidthCm", data=df, jitter=True, edgecolor="gray")
plt.show()

# %%
x = pd.plotting.andrews_curves(df.drop("Id", axis=1), "Species",colormap='rainbow')
x.plot()
plt.show()

# %%
y = pd.plotting.parallel_coordinates(df.drop("Id", axis=1), "Species",colormap='brg')
plt.show()

# %% [markdown]
# # K Means Clustering

# %%
X= df.drop('Species',axis =1)
y = df['Species']

# %%
Error =[]
for i in range(1, 11):
    kmeans = KMeans(n_clusters = i).fit(X)
    kmeans.fit(X)
    Error.append(kmeans.inertia_)
import matplotlib.pyplot as plt
plt.plot(range(1, 11), Error)
plt.title('Elbow method')
plt.xlabel('No of clusters')
plt.ylabel('Error')
plt.show()

# %%
kmeans = KMeans(n_clusters = 3)

# %%
kmeans.fit(X)
y_pred = kmeans.predict(X)

# %%
plt.scatter(X.iloc[:, 0], X.iloc[:, 1], c=y_pred, s=50, cmap='viridis')
centers = kmeans.cluster_centers_
plt.scatter(centers[:, 0], centers[:, 1], c='red', s=200, alpha=0.5)

# %% [markdown]
# # Optimum number of clusters

# %%
print('no. of clusters for iris data are:3')
# Out:
# no. of clusters for iris data are:3
